# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, NotRequired

# %%
class BMIState(TypedDict):
    weight_kg: float
    height_m: float
    bmi: NotRequired[float]
    category: NotRequired[str]

# %%
def calculate_bmi(state: BMIState) -> BMIState:
    weight = state.get('weight_kg')
    height = state.get('height_m')

    bmi = weight/(height**2)
    state['bmi'] = round(bmi, 1)

    return state

# %%
def label_bmi(state: BMIState) -> BMIState:
    bmi = state.get('bmi')

    if bmi is None:
        raise ValueError("BMI has not been calculated")

    if bmi < 18.5:
        category = "Underweight"
    elif bmi < 25:
        category = "Normal weight"
    elif bmi < 30:
        category = "Overweight"
    else:
        category = "Obese"

    state["category"] = category
    return state

# %%
graph = StateGraph(BMIState)

graph.add_node('calculate_bmi', calculate_bmi)
graph.add_node('label_bmi', label_bmi)

graph.add_edge(START, 'calculate_bmi')
graph.add_edge('calculate_bmi', 'label_bmi')
graph.add_edge('label_bmi',END)

workflow = graph.compile()

# %%
initial_state: BMIState = {'weight_kg': 70, 'height_m': 1.81}
final_state = workflow.invoke(initial_state)

# %%
print(final_state)
# Out:
# {'weight_kg': 70, 'height_m': 1.81, 'bmi': 21.4, 'category': 'Normal weight'}
